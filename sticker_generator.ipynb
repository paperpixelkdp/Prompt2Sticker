# %% [markdown]
# # 🎨 Prompt2Sticker
#
# **Free AI Sticker Generator using Stable Diffusion XL.**
#
# This notebook runs the Prompt2Sticker app, allowing you to generate print-ready sticker sheets from text prompts.

# %%
# 1. SETUP
# Clone the repository and install dependencies

import os

REPO_URL = "https://github.com/paperpixelkdp/Prompt2Sticker.git"
REPO_NAME = "Prompt2Sticker"
PROJECT_PATH = f"/content/{REPO_NAME}"

# %cd /content

if not os.path.exists(REPO_NAME):
    print("⏳ Cloning repository...")
    # !git clone {REPO_URL}

# %cd {PROJECT_PATH}

# Fix for Colab's pre-installed numpy conflict
print("⏳ Cleaning up environment...")
# !pip uninstall -y numpy cupy-cuda12x

print("⏳ Installing dependencies...")
# !pip install -r requirements.txt

print("✅ Setup complete!")

# %%
# 2. RUN APP
# Launches the StickerFab interface

import sys
sys.path.append(f"{PROJECT_PATH}/src")

# We will run the app directly
# !python src/app.py
